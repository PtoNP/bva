# %%
import pandas as pd

# %%
# !pwd
# Out:
# /home/konstantin/code/PtoNP/bva

# %%
df = pd.read_csv ('./input_data/params_court.csv')
# Out:
#    Unnamed: 0    type version originX originY   left  top  width  height  \
# 0           0  circle   4.4.0    left  center  179.5  159      6       6
# 1           1  circle   4.4.0    left  center  371.5  156      6       6
# 2           2  circle   4.4.0    left  center  417.5  379      6       6
# 3           3  circle   4.4.0    left  center  129.5  383      6       6
# 4           4  circle   4.4.0    left  center  175.5  198      6       6
# 5           5  circle   4.4.0    left  center  373.5  195      6       6
#
#                      fill  ... visible  backgroundColor fillRule paintFirst  \
# 0  rgba(255, 165, 0, 0.3)  ...    True              NaN  nonzero       fill
# 1  rgba(255, 165, 0, 0.3)  ...    True              NaN  nonzero       fill
# 2  rgba(255, 165, 0, 0.3)  ...    True              NaN  nonzero       fill
# 3  rgba(255, 165, 0, 0.3)  ...    True              NaN  nonzero       fill
# ...
